# %%
from selenium import webdriver

browser = webdriver.Chrome(r'C:\Users\dbqhr\Downloads\chromedriver_win32 (1)\chromedriver.exe')
browser.get('https://www.naver.com/')

# %%
elem = browser.find_element_by_class_name("link_login")
elem
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="be53ba7a39e27e54dee3c8dc2a08aea3", element="7c15b82b-b410-4d09-92a3-b49ebf0a96ea")>

# %%
elem.click() # 로그인 클릭
browser.back() #뒤로가기
browser.forward() # 앞으로 가기 
browser.refresh() # 새로 고침

# %%
elem =browser.find_element_by_id('query')
elem
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="aeed2a606a82c0c594b9a60dfcf6b2be", element="c0942d5f-c8b6-4294-b6a6-12154731e1b3")>

# %%
from selenium.webdriver.common.keys import Keys #검색창에 입력하고 엔터를 치려면 임포트 해야함
elem.send_keys("나도 코딩") # 검색어 입력
elem.send_keys(Keys.ENTER) # 엔터치기

# %%
elem = browser.find_elements_by_tag_name("a")
elem

# %%
for e in elem:
    e.get_attribute("href")

# %%
browser.get('https://www.daum.net/') #다른 사이트로 이동

# %%
elem = browser.find_element_by_name("q")
elem.send_keys("나도코딩")
elem.send_keys(Keys.ENTER)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="aeed2a606a82c0c594b9a60dfcf6b2be", element="ddeff836-e586-4806-97ae-85319e3d2d1e")>

# %%
elem = browser.find_element_by_xpath('//*[@id="daumBtnSearch"]')
elem.click()

# %%
browser.close() # 현재 탭만 종료
# browser.quit()  # 전체 창 종료

# %% [markdown]
# ## 네이버 항공권

# %%
from selenium import webdriver

browser = webdriver.Chrome(r'C:\Users\dbqhr\Downloads\chromedriver_win32 (1)\chromedriver.exe')
browser.maximize_window() # 창 최대화

url = 'https://m-flight.naver.com/'

browser.get(url)

# %%
# 가는 날 선택 클릭
browser.find_element_by_xpath('//*[@id="__next"]/div/div[1]/div[4]/div/div/div[2]/div[2]/button[1]').click()

# %%
# 출발 일 클릭 
browser.find_element_by_xpath('//*[@id="__next"]/div/div[1]/div[9]/div[2]/div[1]/div[2]/div/div[2]/table/tbody/tr[4]/td[2]/button').click()

# %%
# 돌아오는 날 클릭 
browser.find_element_by_xpath('//*[@id="__next"]/div/div[1]/div[9]/div[2]/div[1]/div[2]/div/div[2]/table/tbody/tr[4]/td[6]/button/b').click()

# %%
#도착지 선택 
browser.find_element_by_xpath('//*[@id="__next"]/div/div[1]/div[4]/div/div/div[2]/div[1]/button[2]').click()
from selenium.webdriver.common.keys import Keys #검색창에 입력하고 엔터를 치려면 임포트 해야함
elem =browser.find_element_by_xpath('//*[@id="__next"]/div/div[1]/div[9]/div[1]/div/input')
elem.send_keys("일본") # 검색어 입력
browser.find_element_by_xpath('//*[@id="__next"]/div/div[1]/div[9]/div[2]/section/div/a[1]').click()

# 항공권 검색 클릭
browser.find_element_by_xpath('//*[@id="__next"]/div/div[1]/div[4]/div/div/button').click()

# %%
elem = browser.find_elements_by_class_name('itemSchedule')
for e in elem:
    print(e.text)
# Out:
# 대한항공
# 11:00ICN
# 13:25NRT
# 직항, 02시간 25분
# ZIPAIR TOKYO
# 08:55NRT
# 11:30ICN
# 직항, 02시간 35분
# 일본항공대한항공 공동운항
# 11:00ICN
# 13:25NRT
# 직항, 02시간 25분
# ZIPAIR TOKYO
# 08:55NRT
# 11:30ICN
# 직항, 02시간 35분
# 대한항공
# 11:00ICN
# 13:25NRT
# 직항, 02시간 25분
# 14:40NRT
# 17:30ICN
# 직항, 02시간 50분
# 일본항공대한항공 공동운항
# 11:00ICN
# 13:25NRT
# 직항, 02시간 25분
# 14:40NRT
# 17:30ICN
# 직항, 02시간 50분
# 대한항공
# 11:00ICN
# 13:25NRT
# 직항, 02시간 25분
# 아시아나항공
# 13:20NRT
# 15:55ICN
# 직항, 02시간 35분
# 일본항공대한항공 공동운항
# 11:00ICN
# 13:25NRT
# 직항, 02시간 25분
# 대한항공
# 14:40NRT
# 17:30ICN
# 직항, 02시간 50분
# 일본항공대한항공 공동운항
# 11:00ICN
# 13:25NRT
# 직항, 02시간 25분
# 아시아나항공
# 13:20NRT
# 15:55ICN
# 직항, 02시간 35분
# 대한항공
# 11:00ICN
# 13:25NRT
# 직항, 02시간 25분
# 일본항공대한항공 공동운항
# 14:40NRT
# 17:30ICN
# 직항, 02시간 50분
# 대한항공
# 11:00ICN
# 13:25NRT
# 직항, 02시간 25분
# ANA아시아나항공 공동운항
# 13:20NRT
# 15:55ICN
# 직항, 02시간 35분
# 일본항공대한항공 공동운항
# 11:00ICN
# 13:25NRT
# 직항, 02시간 25분
# ANA아시아나항공 공동운항
# 13:20NRT
# 15:55ICN
# 직항, 02시간 35분
# 여러항공사대한항공 공동운항
# 동일가 다른 일정4
# ...

# %% [markdown]
# ## 헤드라인 뉴스 가져오기

# %%
import requests
from bs4 import BeautifulSoup

def create_soup(url):
    res = requests.get(url)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, 'lxml')
    return soup

def scrape_headline_news():
    print('**헤드라인 뉴스**')
    url = 'https://news.naver.com'
    soup = create_soup(url)
    news_list = soup.find("div", attrs = {"class":"cjs_channel_card"}).find_all("a",limit= 3)
    for index, news in enumerate(news_list):
        title = news.find('p').get_text().strip()
        print(f"{index+1}. {title}")
        print()

# %%
scrape_headline_news()
# Out:
# **헤드라인 뉴스**
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12080/2880883752.py in <module>
# ----> 1 scrape_headline_news()
#
# ~\AppData\Local\Temp/ipykernel_12080/1241044132.py in scrape_headline_news()
#      14     news_list = soup.find("div", attrs = {"class":"cjs_channel_card"}).find_all("a",limit= 3)
#      15     for index, news in enumerate(news_list):
# ---> 16         title = news.find('p').get_text().strip()
#      17         print(f"{index+1}. {title}")
#      18         print()
#
# AttributeError: 'NoneType' object has no attribute 'get_text'
